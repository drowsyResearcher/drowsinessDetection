# %%
# Clone YOLOv5 repository
# !git clone https://github.com/ultralytics/yolov5.git
# %cd yolov5

# Install dependencies
# !pip install -r requirements.txt

# Install additional dependencies if needed
# !pip install opencv-python
# Out:
# C:\Users\20pra\Downloads\TrainedModelWorking\yolov5
# fatal: destination path 'yolov5' already exists and is not an empty directory.
# ...

# %%
# Train YOLOv5 on your dataset
# !python train.py --img 416 --batch 16 --epochs 100 --data '/content/drive/MyDrive/Colab Notebooks/Dataset/data.yaml' --weights yolov5s.pt --device 0
# Out:
# Streaming output truncated to the last 5000 lines.
#       63/99      1.95G    0.01305   0.004542   0.005123         28        416:  61% 40/66 [00:14<00:08,  3.06it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       63/99      1.95G    0.01308   0.004572   0.005066         30        416:  62% 41/66 [00:14<00:09,  2.66it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       63/99      1.95G    0.01307   0.004561   0.005127         21        416:  64% 42/66 [00:15<00:11,  2.10it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# ...

# %%
import os

# Define the path to the directory, not the file
# Use raw string to avoid issues with backslashes
new_directory = r"D:\MinorProject\TrainedModelWorking"

# Change the current working directory
os.chdir(new_directory)

# Print the new working directory
print("New Directory:", os.getcwd())
# Out:
# New Directory: D:\MinorProject\TrainedModelWorking

# %%
pip install yolov5
# Out:
# ...
#   Using cached yolov5-7.0.13-py37.py38.py39.py310-none-any.whl.metadata (10 kB)
# ...
#   Using cached tensorboard-2.17.1-py3-none-any.whl.metadata (1.6 kB)
# ...
#   Using cached fire-0.6.0-py2.py3-none-any.whl
# ...
#   Using cached boto3-1.35.13-py3-none-any.whl.metadata (6.6 kB)
# ...
#   Using cached sahi-0.11.18-py3-none-any.whl.metadata (17 kB)
# ...
#   Using cached huggingface_hub-0.24.6-py3-none-any.whl.metadata (13 kB)
# ...
#   Using cached roboflow-1.1.44-py3-none-any.whl.metadata (9.7 kB)
# ...
#   Using cached botocore-1.35.13-py3-none-any.whl.metadata (5.7 kB)
# ...
#   Using cached s3transfer-0.10.2-py3-none-any.whl.metadata (1.7 kB)
# ...
#   Using cached opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
#   Using cached opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
#   Using cached absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached grpcio-1.66.1-cp312-cp312-win_amd64.whl.metadata (4.0 kB)
# ...
# Using cached yolov5-7.0.13-py37.py38.py39.py310-none-any.whl (953 kB)
# ...

# %%
import torch  # Import PyTorch

# Load the YOLOv5 model from the Ultralytics hub
model = torch.hub.load('ultralytics/yolov5', 'custom', path='yolov5/runs/train/exp/weights/last.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to C:\Users\20pra/.cache\torch\hub\master.zip
# YOLOv5  2024-9-22 Python-3.12.4 torch-2.4.1+cpu CPU
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File ~/.cache\torch\hub\ultralytics_yolov5_master\hubconf.py:70, in _create(name, pretrained, channels, classes, autoshape, verbose, device)
#      69 try:
# ---> 70     model = DetectMultiBackend(path, device=device, fuse=autoshape)  # detection model
#      71     if autoshape:
#
# File ~/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:489, in DetectMultiBackend.__init__(self, weights, device, dnn, data, fp16, fuse)
#     488 if pt:  # PyTorch
# --> 489     model = attempt_load(weights if isinstance(weights, list) else w, device=device, inplace=True, fuse=fuse)
#     490     stride = max(int(model.stride.max()), 32)  # model stride
#
# ...

# %%
import os
import matplotlib.pyplot as plt
import numpy as np

# Path to the new image
img = '/content/1.jpg'

# Assuming 'model' is already defined and loaded
results = model(img)
results.print()

# Plotting the results
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 9
#       6 img = '/content/1.jpg'
#       8 # Assuming 'model' is already defined and loaded
# ----> 9 results = model(img)
#      10 results.print()
#      12 # Plotting the results
#
# NameError: name 'model' is not defined

# %%
import os
import matplotlib.pyplot as plt
import numpy as np

# Path to the new image
img = '/content/2.jpg'

# Assuming 'model' is already defined and loaded
results = model(img)
results.print()

# Plotting the results
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
plt.show()
# Out:
# /content/yolov5/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# image 1/1: 1080x1920 1 awake
# Speed: 26.9ms pre-process, 237.7ms inference, 0.9ms NMS per image at shape (1, 3, 384, 640)

# %%
import os
import matplotlib.pyplot as plt
import numpy as np

# Path to the new image
img = '/content/3.jpg'

# Assuming 'model' is already defined and loaded
results = model(img)
results.print()

# Plotting the results
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
plt.show()
# Out:
# /content/yolov5/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# image 1/1: 1080x1920 1 drowsy
# Speed: 23.8ms pre-process, 234.5ms inference, 0.9ms NMS per image at shape (1, 3, 384, 640)
